# %% [markdown]
# # Introduction to Pandas

# %% [markdown]
# #### Membuat Objek DataFrames
# - Buatlah objek dataframes dari objek dictionary, Bebas!

# %%
import pandas as pd

data_ekstra = {
    'kelas' : ['11A','11B','11C'],
    'basket' : [13,4,9],
    'futsal' : [6,15,10],
    'bulutangkis' : [8,7,10]
            }

df_ekstra = pd.DataFrame(data = data_ekstra)
df_ekstra
# Out:
#   kelas  basket  futsal  bulutangkis
# 0   11A      13       6            8
# 1   11B       4      15            7
# 2   11C       9      10           10

# %% [markdown]
# #### Membaca data dari file
#
# Download file bernama [diamonds.csv](https://drive.google.com/uc?export=download&id=1qQiM9utQUThTPq8jk8stPMh_y2zfqYOd), kemudian baca data tersebut dan assign ke dalam suatu variabel kemudian print.

# %%
df_from_csv = pd.read_csv('data/diamonds.csv')
display(df_from_csv)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %% [markdown]
# #### DataFrame vs Series
# - Buatlah suatu data series

# %%
series_a = pd.Series(['Jambu','Jeruk','Semangka','Anggur'],index = ['a','b','c','d'])
print(series_a)
# Out:
# a       Jambu
# b       Jeruk
# c    Semangka
# d      Anggur
# dtype: object

# %% [markdown]
# #### Pemeriksaan Data Sederhana
#
# Pada soal ini cobalah suatu metode dari pandas untuk mengetahui beberapa data pertama dan beberapa data terakhir. kemudian sebutkan nilai dari:
# - baris pertama dari column price
# - baris terakhir dari column color

# %%
display(df_from_csv.price.head(1))
# Out:
# 0    326
# Name: price, dtype: int64

# %%
display(df_from_csv.color.tail(1))
# Out:
# 53939    D
# Name: color, dtype: object

# %% [markdown]
# ####  Deskriptif Statistik
# - Gunakan suatu metode dari pandas untuk mengetahui deskriptif statistik dari suatu data
# - Berapa nilai rata-rata dari column price
# - Berapa nilai standar deviasi dari column depth
# - Berapa nilai maximum dari column carat

# %%
df_desc = df_from_csv.describe()
df_desc
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
print('b. Rata-rata column price =', df_desc.carat['mean'])
print('c. Standar deviasi column depth =', df_desc.depth['std'])
print('d. Nilai maximum column carat =', df_desc.carat['max'])
# Out:
# b. Rata-rata column price = 0.7979397478680014
# c. Standar deviasi column depth = 1.432621318833661
# d. Nilai maximum column carat = 5.01

# %% [markdown]
# ---
#
# ---
#
# ---

# %% [markdown]
# # Accessing & Indexing Dataframe

# %%
import pandas as pd
import random

# %%
pelajaran = ['Matematika', 'Fisika', 'Biologi', 'Kimia', 'Geologi', 'Ekonomi']
kelas = ['12A', '12B', '12C', '12D']

hasil_nilai = {
    'siswa_id' : range(1, 21),
    'pelajaran' : [random.choice(pelajaran) for i in range(20)],
    'nilai' : [random.choice(range(0, 100)) for i in range(20)],
    'jenis-kelamin' : [random.choice(['laki-laki', 'perempuan']) for i in range(20)],
    'kelas' : [random.choice(kelas) for i in range(20)]
}

df = pd.DataFrame(hasil_nilai)
df.head()
# Out:
#    siswa_id   pelajaran  nilai jenis-kelamin kelas
# 0         1  Matematika     10     laki-laki   12D
# 1         2       Kimia     99     perempuan   12A
# 2         3  Matematika     29     laki-laki   12C
# 3         4  Matematika     48     laki-laki   12A
# 4         5  Matematika     39     perempuan   12C

# %% [markdown]
# ####  Indexing
#
# - Lakukan indexing terhadap dataframe untuk mengakses column nilai dan kelas saja
# - Lakukan indexing terhadap dataframe untuk mengakses row 5 sampai 10 beserta column pelajaran dan nilai

# %%
display(df[['nilai', 'kelas']])
# Out:
#     nilai kelas
# 0      10   12D
# 1      99   12A
# 2      29   12C
# 3      48   12A
# 4      39   12C
# 5      28   12C
# 6      71   12A
# 7       4   12D
# 8      85   12B
# 9      46   12B
# 10     94   12C
# 11     26   12D
# 12     65   12A
# 13     85   12C
# 14     70   12D
# 15     17   12D
# 16     37   12B
# 17     80   12C
# 18     97   12D
# 19     32   12D

# %%
df.loc[4:9,'pelajaran':'nilai']
# Out:
#     pelajaran  nilai
# 4  Matematika     39
# 5  Matematika     28
# 6      Fisika     71
# 7       Kimia      4
# 8     Ekonomi     85
# 9  Matematika     46

# %% [markdown]
# #### Filter DataFrame Dengan Boolean
#
# - Tampilkan semua data siswa pada mata pelajaran Ekonomi dan Fisika
# - Tampilkan semua data siswa yang mempunyai nilai lebih dari 50 di mata pelajaran Kimia
# - Tampilkan semua data yang mempunyai nilai lebih dari 70, berjnis kelamin perempuan dan di kelas 12C

# %%
#Data siswa pada mata pelajaran Ekonomi dan Fisika
df[(df.pelajaran == 'Ekonomi') | (df.pelajaran == 'Fisika')]
# Out:
#     siswa_id pelajaran  nilai jenis-kelamin kelas
# 6          7    Fisika     71     perempuan   12A
# 8          9   Ekonomi     85     laki-laki   12B
# 14        15    Fisika     70     perempuan   12D
# 16        17    Fisika     37     laki-laki   12B

# %%
#Menampilkan data siswa yang mempunyai nilai lebih dari 50 di mapel Kimia
df[(df.pelajaran == 'Kimia') & (df.nilai > 50)]
# Out:
#     siswa_id pelajaran  nilai jenis-kelamin kelas
# 1          2     Kimia     99     perempuan   12A
# 17        18     Kimia     80     perempuan   12C

# %%
#Menampilkan data siswa yang mempunyai nilai lebih dari 70, perempuan, dan kelas 12C

df[(df.nilai>70) & (df['jenis-kelamin'] == 'perempuan') & (df.kelas == '12C')]
# Out:
#     siswa_id   pelajaran  nilai jenis-kelamin kelas
# 10        11  Matematika     94     perempuan   12C
# 17        18       Kimia     80     perempuan   12C

# %% [markdown]
# #### Data Transformation
#
# Lakukan data transformasi terhadap column 'nilai' dengan fungsi transformasi, berikut rumus dari normalisasi
#
# ![alt text](https://drive.google.com/uc?id=1wed-EbRSTA0JP1ceDp6lcKBqH2yJ4aa3)

# %%
df['nilai'] = df[['nilai']].apply(lambda nilai : (nilai-nilai.min())/(nilai.max()-nilai.min()))
df.nilai
# Out:
# 0     0.063158
# 1     1.000000
# 2     0.263158
# 3     0.463158
# 4     0.368421
# 5     0.252632
# 6     0.705263
# 7     0.000000
# 8     0.852632
# 9     0.442105
# 10    0.947368
# 11    0.231579
# 12    0.642105
# 13    0.852632
# 14    0.694737
# 15    0.136842
# 16    0.347368
# 17    0.800000
# 18    0.978947
# 19    0.294737
# Name: nilai, dtype: float64

# %%
#DataFrame setelah kolom nilai ditransformasi b

df
# Out:
#     siswa_id   pelajaran     nilai jenis-kelamin kelas
# 0          1  Matematika  0.063158     laki-laki   12D
# 1          2       Kimia  1.000000     perempuan   12A
# 2          3  Matematika  0.263158     laki-laki   12C
# 3          4  Matematika  0.463158     laki-laki   12A
# 4          5  Matematika  0.368421     perempuan   12C
# 5          6  Matematika  0.252632     perempuan   12C
# 6          7      Fisika  0.705263     perempuan   12A
# 7          8       Kimia  0.000000     laki-laki   12D
# 8          9     Ekonomi  0.852632     laki-laki   12B
# 9         10  Matematika  0.442105     perempuan   12B
# 10        11  Matematika  0.947368     perempuan   12C
# 11        12     Biologi  0.231579     laki-laki   12D
# 12        13     Geologi  0.642105     perempuan   12A
# 13        14     Geologi  0.852632     laki-laki   12C
# 14        15      Fisika  0.694737     perempuan   12D
# 15        16     Biologi  0.136842     perempuan   12D
# ...

# %% [markdown]
# ---
#
# ---
#
# ---

# %% [markdown]
# # DataFrame Re-Shapping

# %% [markdown]
# #### Reshapping Data

# %%
import pandas as pd
import random

# %%
data = {
    'Tipe Ujian' : ['UTS1', 'UAS1', 'UTS2', 'UAS2']*3,
    'Mata Pelajaran' : ['Fisika']*4 + ['Matematika']*4+['Statistika']*4,
    'Rata2 Waktu Belajar (menit)' : [random.choice(range(200, 800)) for i in range(12)],
    'Rata2 Nilai Ujian' : [random.choice(range(40, 100)) for i in range(12)] 
}
df = pd.DataFrame(data)
df
# Out:
#    Tipe Ujian Mata Pelajaran  Rata2 Waktu Belajar (menit)  Rata2 Nilai Ujian
# 0        UTS1         Fisika                          776                 56
# 1        UAS1         Fisika                          407                 48
# 2        UTS2         Fisika                          569                 89
# 3        UAS2         Fisika                          574                 78
# 4        UTS1     Matematika                          795                 49
# 5        UAS1     Matematika                          274                 94
# 6        UTS2     Matematika                          612                 83
# 7        UAS2     Matematika                          397                 48
# 8        UTS1     Statistika                          351                 67
# 9        UAS1     Statistika                          216                 49
# 10       UTS2     Statistika                          526                 88
# ...

# %%
#Pivot Data

nilai_pivot = df.pivot_table(index = 'Tipe Ujian', columns = 'Mata Pelajaran', 
                             values = ['Rata2 Nilai Ujian','Rata2 Waktu Belajar (menit)'], 
                             aggfunc = 'mean')
nilai_pivot
# Out:
#                Rata2 Nilai Ujian                        \
# Mata Pelajaran            Fisika Matematika Statistika
# Tipe Ujian
# UAS1                          48         94         49
# UAS2                          78         48         95
# UTS1                          56         49         67
# UTS2                          89         83         88
#
#                Rata2 Waktu Belajar (menit)
# Mata Pelajaran                      Fisika Matematika Statistika
# Tipe Ujian
# UAS1                                   407        274        216
# UAS2                                   574        397        277
# UTS1                                   776        795        351
# UTS2                                   569        612        526

# %%
data = {
    'Hari' : ['Sabtu', 'Minggu'],
    'Kebun Binatang' : [271, 399],
    'Dufan' : [501, 700],
    'Disney' : [1000, 1001],
    'Bali' : [900, 803]
}
df = pd.DataFrame(data).set_index('Hari')
df
# Out:
#         Kebun Binatang  Dufan  Disney  Bali
# Hari
# Sabtu              271    501    1000   900
# Minggu             399    700    1001   803

# %%
display(df.reset_index().melt(id_vars = 'Hari',var_name='Tempat Hiburan',value_name='Pengunjung'))
# Out:
#      Hari  Tempat Hiburan  Pengunjung
# 0   Sabtu  Kebun Binatang         271
# 1  Minggu  Kebun Binatang         399
# 2   Sabtu           Dufan         501
# 3  Minggu           Dufan         700
# 4   Sabtu          Disney        1000
# 5  Minggu          Disney        1001
# 6   Sabtu            Bali         900
# 7  Minggu            Bali         803

# %%
data = {
    'Tipe Ujian' : ['UTS1', 'UAS1']*3,
    'Mata Pelajaran' :['Statistika', 'Fisika', 'Fisika', 'Statistika', 'Fisika', 'Statistika'],
    'Jumlah Peserta' : [14, 17, 12, 16, 14, 13]
}
df = pd.DataFrame(data).set_index('Tipe Ujian')
df
# Out:
#            Mata Pelajaran  Jumlah Peserta
# Tipe Ujian
# UTS1           Statistika              14
# UAS1               Fisika              17
# UTS1               Fisika              12
# UAS1           Statistika              16
# UTS1               Fisika              14
# UAS1           Statistika              13

# %% [markdown]
# #### Pivoting and Aggregating

# %%
data = {
    'Tipe Ujian' : ['UTS1', 'UAS1']*3,
    'Mata Pelajaran' :['Statistika', 'Fisika', 'Fisika', 'Statistika', 'Fisika', 'Statistika'],
    'Jumlah Peserta' : [14, 17, 12, 16, 14, 13]
}
df = pd.DataFrame(data).set_index('Tipe Ujian')
df
# Out:
#            Mata Pelajaran  Jumlah Peserta
# Tipe Ujian
# UTS1           Statistika              14
# UAS1               Fisika              17
# UTS1               Fisika              12
# UAS1           Statistika              16
# UTS1               Fisika              14
# UAS1           Statistika              13

# %% [markdown]
# Terdapat duplikasi data pada data jumlah peserta ujian untuk suatu tipe ujian dan mata pelajaran tertentu. Kita akan melakukan aggregasi berjenis jumlah untuk data tersebut.

# %%
ujian_pivot = df.pivot_table(index = 'Tipe Ujian',columns = 'Mata Pelajaran',values = 'Jumlah Peserta',aggfunc = 'sum')
ujian_pivot
# Out:
# Mata Pelajaran  Fisika  Statistika
# Tipe Ujian
# UAS1                17          29
# UTS1                26          14

# %% [markdown]
# ---
#
# ---
#
# ---

# %% [markdown]
# # Data Grouping

# %%
import pandas as pd

# %%
df = pd.read_csv('data/diamonds.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# Columns Metadata:
#
# carat: berat diamond
#
# cut: kualitas diamond
#
# color: warna diamond
#
# clarity: level kemurnian diamonds
#
# depth: tinggi dari diamond tabel
#
# table: lebar  dari diamond tabel
#
# price: harga diamond ($US)
#
# x: panjang
#
# y: lebar
#
# z: kedalaaman

# %% [markdown]
# #### Process Grouping

# %%
#Grup data berdasarkan cut (kualitas) dan melakukan agregasi fungsi rata-rata

df_cut = df.groupby('cut').mean()
df_cut
# Out:
#               carat      depth      table        price         x         y  \
# cut
# Fair       1.046137  64.041677  59.053789  4358.757764  6.246894  6.182652
# Good       0.849185  62.365879  58.694639  3928.864452  5.838785  5.850744
# Ideal      0.702837  61.709401  55.951668  3457.541970  5.507451  5.520080
# Premium    0.891955  61.264673  58.746095  4584.257704  5.973887  5.944879
# Very Good  0.806381  61.818275  57.956150  3981.759891  5.740696  5.770026
#
#                   z
# cut
# Fair       3.982770
# Good       3.639507
# Ideal      3.401448
# Premium    3.647124
# Very Good  3.559801

# %% [markdown]
# ####  Grouping Some Column based on Multiple Criteria

# %% [markdown]
# Lakukan groupby pada data berdasarkan kriteria cut (kualitas) dan color (warna) secara berurutan, dengan aggregasi pada column carat, table, dan price saja. dengan fungsi agregasi rata-rata.

# %%
df_cc = df.groupby(['cut','color'])[['carat','table','price']].agg('mean')
df_cc
# Out:
#                     carat      table        price
# cut       color
# Fair      D      0.920123  58.969325  4291.061350
#           E      0.856607  59.364732  3682.312500
#           F      0.904712  59.453205  3827.003205
#           G      1.023822  58.773248  4239.254777
#           H      1.219175  58.696370  5135.683168
#           I      1.198057  59.237143  4685.445714
#           J      1.341176  58.917647  4975.655462
# Good      D      0.744517  58.541541  3405.382175
#           E      0.745134  58.779957  3423.644159
#           F      0.775930  58.910891  3495.750275
#           G      0.850896  58.471986  4123.482204
#           H      0.914729  58.611111  4276.254986
#           I      1.057222  58.773946  5078.532567
#           J      1.099544  58.813029  4574.172638
# Ideal     D      0.565766  55.965632  2629.094566
#           E      0.578401  55.967461  2597.550090
#           F      0.655829  55.924203  3374.939362
# ...

# %% [markdown]
# #### Group by Multiple Aggregate based on Multiple Criteria

# %% [markdown]
# Lakukan groupby pada data berdasarkan kriteria cut(kualitas) dan color (warna) secara berurutan kemudian aggregasi objek group by nya dengan fungsi rata2 dan median.

# %%
df_multiple = df.groupby(['cut','color'])[['carat','depth','table','price','x','y','z']].agg(['mean','median'])
df_multiple
# Out:
#                     carat             depth             table         \
#                      mean median       mean median       mean median
# cut       color
# Fair      D      0.920123  0.900  64.048466   64.8  58.969325   58.0
#           E      0.856607  0.900  63.319643   64.8  59.364732   59.0
#           F      0.904712  0.900  63.508013   64.8  59.453205   59.0
#           G      1.023822  0.980  64.339809   65.0  58.773248   58.0
#           H      1.219175  1.010  64.585149   65.1  58.696370   58.0
#           I      1.198057  1.010  64.220571   65.1  59.237143   58.0
#           J      1.341176  1.030  64.357143   65.0  58.917647   58.0
# Good      D      0.744517  0.700  62.365710   63.4  58.541541   58.0
#           E      0.745134  0.700  62.203751   63.3  58.779957   58.0
#           F      0.775930  0.710  62.202310   63.2  58.910891   59.0
#           G      0.850896  0.900  62.526636   63.4  58.471986   58.0
# ...

# %% [markdown]
# #### Group By With Different Aggregation for specific Column

# %% [markdown]
# Lakukan group by pada data berdasarkan criteria cut(kualitas), kemudian aggreagate dengan fungsi max pada column price dan fungsi min pada column carat.

# %%
df_spec = df.groupby('cut')[['price','carat']].agg({'price':'max','carat':'min'})
df_spec
# Out:
#            price  carat
# cut
# Fair       18574   0.22
# Good       18788   0.23
# Ideal      18806   0.20
# Premium    18823   0.20
# Very Good  18818   0.20

# %% [markdown]
# #### Group By With Custom Function

# %% [markdown]
# Lakukan groupby pada data berdasarkan criteria cut(kualitas), kemudian lakukan aggregasi dengan fungsi standar deviasi pada column carat dan fungsi rentang nilai antara max dan min pada column price.

# %%
import numpy as np

df_func = df.groupby('cut')[['price','carat']].agg({'price':np.ptp,'carat':'std'})
df_func
# Out:
#            price     carat
# cut
# Fair       18237  0.516404
# Good       18461  0.454054
# Ideal      18480  0.432876
# Premium    18497  0.515262
# Very Good  18482  0.459435

# %% [markdown]
# ---
#
# ---
#
# ---

# %% [markdown]
# # Data Merging

# %% [markdown]
# #### Penggabungan Data 1

# %% [markdown]
# Pada soal ini gunakan data names1881.csv dan names1981.csv, data ini berisi nama bayi yang lahir pada tahun 1881 atau 1981 di Amerika.

# %%
import pandas as pd

# %%
#read data

df1 = pd.read_csv('data/names1881.csv', names = ['Name','Gender','Count'])
df2 = pd.read_csv('data/names1981.csv', names = ['Name','Gender','Count'])

# periksa dimensi dari kedua data
print("Jumlah Dimensi data 'names1881.csv' :",df1.shape)
print("Jumlah Baris data 'names1981.csv' :",df2.shape)

# gabungkan data
df = pd.concat([df1,df2])
display(df)

# periksa dimensi data hasil gabungan
print("Jumlah dimensi data setelah penggabungan : ",df.shape)
# Out:
# Jumlah Dimensi data 'names1881.csv' : (1935, 3)
# Jumlah Baris data 'names1981.csv' : (19455, 3)
#             Name Gender  Count
# 0           Mary      F   6919
# 1           Anna      F   2698
# 2           Emma      F   2034
# 3      Elizabeth      F   1852
# 4       Margaret      F   1658
# ...          ...    ...    ...
# 19450   Zeferino      M      5
# 19451    Zerrick      M      5
# 19452   Zimbabwe      M      5
# 19453     Zoltan      M      5
# 19454     Zuriel      M      5
#
# [21390 rows x 3 columns]
# Jumlah dimensi data setelah penggabungan :  (21390, 3)

# %% [markdown]
# #### Penggabungan Data 2

# %% [markdown]
# data1 = {
#     'id' : [1, 2, 3, 4],
#     'Feature1' : ['a1', 'a2', 'a3', 'a4'],
#     'Feature2' : ['b1', 'b2', 'b3', 'b4']
# }
#
# data2 = {
#     'id' : [3, 4, 5 ,6, 7],
#     'Feature3' : ['c1', 'c2', 'c3', 'c4', 'c5']
# }
#
# df1= pd.DataFrame(data1)
# df2= pd.DataFrame(data2)
#
# print(df1)
# print(df2)

# %%
# join data
df_outer_join = pd.merge (df1,df2,how = 'outer', on = 'id')
display(df_outer_join)

df_inner_join = pd.merge (df1,df2,how = 'inner', on = 'id')
display(df_inner_join)

df_left_join = pd.merge (df1,df2,how = 'left', on = 'id')
display(df_left_join)

df_right_join = pd.merge (df1,df2,how = 'right', on = 'id')
display(df_right_join)
# Out:
#    id Feature1 Feature2 Feature3
# 0   1       a1       b1      NaN
# 1   2       a2       b2      NaN
# 2   3       a3       b3       c1
# 3   4       a4       b4       c2
# 4   5      NaN      NaN       c3
# 5   6      NaN      NaN       c4
# 6   7      NaN      NaN       c5
#    id Feature1 Feature2 Feature3
# 0   3       a3       b3       c1
# 1   4       a4       b4       c2
#    id Feature1 Feature2 Feature3
# 0   1       a1       b1      NaN
# 1   2       a2       b2      NaN
# 2   3       a3       b3       c1
# 3   4       a4       b4       c2
#    id Feature1 Feature2 Feature3
# 0   3       a3       b3       c1
# 1   4       a4       b4       c2
# 2   5      NaN      NaN       c3
# 3   6      NaN      NaN       c4
# 4   7      NaN      NaN       c5

# %% [markdown]
# #### Penggabungan Data berbeda label column Key

# %%
data1 = {
    'key_data1' : [1, 2, 3, 4],
    'Feature1' : ['a1', 'a2', 'a3', 'a4'],
    'Feature2' : ['b1', 'b2', 'b3', 'b4']
}

data2 = {
    'key_data2' : [3, 4, 5 ,6, 7],
    'Feature3' : ['c1', 'c2', 'c3', 'c4', 'c5']
}

df1= pd.DataFrame(data1)
df2= pd.DataFrame(data2)

print(df1)
print(df2)
# Out:
#    key_data1 Feature1 Feature2
# 0          1       a1       b1
# 1          2       a2       b2
# 2          3       a3       b3
# 3          4       a4       b4
#    key_data2 Feature3
# 0          3       c1
# 1          4       c2
# 2          5       c3
# 3          6       c4
# 4          7       c5

# %%
#Penggabungan kedua data
df_gabung = pd.merge(df1, df2, left_on = 'key_data1',right_on = 'key_data2')

df_gabung
# Out:
#    key_data1 Feature1 Feature2  key_data2 Feature3
# 0          3       a3       b3          3       c1
# 1          4       a4       b4          4       c2
